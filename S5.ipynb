# %%
from model import Session5Model
from utils import fit_model, get_dataloaders, visualize_data, model_summary, plot_data

# %%
train_loader, test_loader = get_dataloaders()

# %%
visualize_data(train_loader, num_figures=12, label="Train Set")

# %%
visualize_data(test_loader, num_figures=12, label="Test Set")

# %%
model = Session5Model()
model_summary(model, input_size=(1, 1, 28, 28))
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                  Kernel Shape              Input Shape               Output Shape              Param #
# ============================================================================================================================================
# Session5Model (Session5Model)            --                        [1, 1, 28, 28]            [1, 10]                   --
# ├─Conv2d (conv1)                         [3, 3]                    [1, 1, 28, 28]            [1, 32, 26, 26]           288
# ├─Conv2d (conv2)                         [3, 3]                    [1, 32, 26, 26]           [1, 64, 24, 24]           18,432
# ├─Conv2d (conv3)                         [3, 3]                    [1, 64, 12, 12]           [1, 128, 10, 10]          73,728
# ├─Conv2d (conv4)                         [3, 3]                    [1, 128, 10, 10]          [1, 256, 8, 8]            294,912
# ├─Linear (fc1)                           --                        [1, 4096]                 [1, 50]                   204,800
# ├─Linear (fc2)                           --                        [1, 50]                   [1, 10]                   500
# ============================================================================================================================================
# Total params: 592,660
# Trainable params: 592,660
# Non-trainable params: 0
# Total mult-adds (M): 37.26
# ============================================================================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.70
# Params size (MB): 2.37
# Estimated Total Size (MB): 3.08
# ============================================================================================================================================

# %%
model = Session5Model()
results = fit_model(model, train_loader, test_loader, 20)
# Out:
# Epoch 1
# Train set: LR = 0.01 | Loss = 0.28 | Batch = 117 | Accuracy = 62.70 |: 100%|██████████| 118/118 [00:10<00:00, 11.39it/s]
# Test set: Average loss = 0.0004 | Accuracy = 9414/10000 (94.14%)
#
# Epoch 2
# Train set: LR = 0.01 | Loss = 0.28 | Batch = 117 | Accuracy = 94.48 |: 100%|██████████| 118/118 [00:09<00:00, 11.93it/s]
# Test set: Average loss = 0.0002 | Accuracy = 9667/10000 (96.67%)
#
# Epoch 3
# Train set: LR = 0.01 | Loss = 0.10 | Batch = 117 | Accuracy = 96.42 |: 100%|██████████| 118/118 [00:10<00:00, 11.23it/s]
# Test set: Average loss = 0.0001 | Accuracy = 9795/10000 (97.95%)
#
# Epoch 4
# Train set: LR = 0.01 | Loss = 0.10 | Batch = 117 | Accuracy = 97.17 |: 100%|██████████| 118/118 [00:10<00:00, 11.17it/s]
# Test set: Average loss = 0.0001 | Accuracy = 9853/10000 (98.53%)
#
# Epoch 5
# Train set: LR = 0.01 | Loss = 0.05 | Batch = 117 | Accuracy = 97.61 |: 100%|██████████| 118/118 [00:13<00:00,  9.04it/s]
# Test set: Average loss = 0.0001 | Accuracy = 9863/10000 (98.63%)
#
# Epoch 6
# Train set: LR = 0.01 | Loss = 0.05 | Batch = 117 | Accuracy = 97.79 |: 100%|██████████| 118/118 [00:16<00:00,  7.18it/s]
# Test set: Average loss = 0.0001 | Accuracy = 9884/10000 (98.84%)
#
# Epoch 7
# Train set: LR = 0.01 | Loss = 0.04 | Batch = 117 | Accuracy = 98.08 |: 100%|██████████| 118/118 [00:11<00:00, 10.21it/s]
# Test set: Average loss = 0.0001 | Accuracy = 9871/10000 (98.71%)
#
# Epoch 8
# Train set: LR = 0.01 | Loss = 0.02 | Batch = 117 | Accuracy = 98.25 |: 100%|██████████| 118/118 [00:11<00:00, 10.20it/s]
# Test set: Average loss = 0.0001 | Accuracy = 9896/10000 (98.96%)
#
# Epoch 9
# Train set: LR = 0.01 | Loss = 0.05 | Batch = 117 | Accuracy = 98.28 |: 100%|██████████| 118/118 [00:10<00:00, 11.15it/s]
# Test set: Average loss = 0.0001 | Accuracy = 9900/10000 (99.00%)
#
# Epoch 10
# Train set: LR = 0.01 | Loss = 0.04 | Batch = 117 | Accuracy = 98.43 |: 100%|██████████| 118/118 [00:10<00:00, 10.78it/s]
# Test set: Average loss = 0.0001 | Accuracy = 9900/10000 (99.00%)
#
# Epoch 11
# Train set: LR = 0.01 | Loss = 0.11 | Batch = 117 | Accuracy = 98.52 |: 100%|██████████| 118/118 [00:10<00:00, 11.14it/s]
# Test set: Average loss = 0.0001 | Accuracy = 9909/10000 (99.09%)
#
# Epoch 12
# Train set: LR = 0.01 | Loss = 0.04 | Batch = 117 | Accuracy = 98.62 |: 100%|██████████| 118/118 [00:11<00:00, 10.33it/s]
# Test set: Average loss = 0.0001 | Accuracy = 9910/10000 (99.10%)
#
# Epoch 13
# Train set: LR = 0.01 | Loss = 0.07 | Batch = 117 | Accuracy = 98.65 |: 100%|██████████| 118/118 [00:11<00:00, 10.66it/s]
# Test set: Average loss = 0.0001 | Accuracy = 9917/10000 (99.17%)
#
# Epoch 14
# Train set: LR = 0.01 | Loss = 0.09 | Batch = 117 | Accuracy = 98.79 |: 100%|██████████| 118/118 [00:11<00:00, 10.68it/s]
# Test set: Average loss = 0.0001 | Accuracy = 9886/10000 (98.86%)
#
# Epoch 15
# Train set: LR = 0.01 | Loss = 0.01 | Batch = 117 | Accuracy = 98.86 |: 100%|██████████| 118/118 [00:12<00:00,  9.66it/s]
# Test set: Average loss = 0.0000 | Accuracy = 9910/10000 (99.10%)
#
# Epoch 16
# Train set: LR = 0.001 | Loss = 0.01 | Batch = 117 | Accuracy = 99.04 |: 100%|██████████| 118/118 [00:13<00:00,  8.57it/s]
# Test set: Average loss = 0.0000 | Accuracy = 9923/10000 (99.23%)
#
# Epoch 17
# Train set: LR = 0.001 | Loss = 0.03 | Batch = 117 | Accuracy = 99.14 |: 100%|██████████| 118/118 [00:12<00:00,  9.57it/s]
# Test set: Average loss = 0.0000 | Accuracy = 9925/10000 (99.25%)
#
# Epoch 18
# Train set: LR = 0.001 | Loss = 0.01 | Batch = 117 | Accuracy = 99.17 |: 100%|██████████| 118/118 [00:11<00:00, 10.17it/s]
# Test set: Average loss = 0.0000 | Accuracy = 9923/10000 (99.23%)
#
# Epoch 19
# Train set: LR = 0.001 | Loss = 0.08 | Batch = 117 | Accuracy = 99.18 |: 100%|██████████| 118/118 [00:11<00:00, 10.28it/s]
# Test set: Average loss = 0.0000 | Accuracy = 9926/10000 (99.26%)
#
# Epoch 20
# Train set: LR = 0.001 | Loss = 0.04 | Batch = 117 | Accuracy = 99.18 |: 100%|██████████| 118/118 [00:12<00:00,  9.81it/s]
# Test set: Average loss = 0.0000 | Accuracy = 9924/10000 (99.24%)

# %%
plot_data([
        results['train_losses'],
        results['train_accuracies'],
        results['test_losses'],
        results['test_accuracies'],
    ], [
        'Train Losses',
        'Train Accuracies',
        'Test Losses',
        'Test Accuracies',
    ])
